# %% [markdown]
# # 01 — Eksplorimi Fillestar i Datasetit
#
# **Hapi 1.1** — Online Retail Analytics Platform
#
# Qëllimi i këtij notebook-u: të ngarkojë datasetin "Online Retail II" (UCI), të shikojë strukturën e tij, dhe të dokumentojë problemet e gjetura (vlera mungesë, duplicates, etj.), si input për `clean_data()` në `src/data_cleaning.py`.

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)

# %% [markdown]
# ## Ngarkimi i të dhënave
#
# Dataseti ngarkohet direkt online nga UCI Machine Learning Repository.

# %%
DATA_URL = "https://archive.ics.uci.edu/ml/machine-learning-databases/00502/online_retail_II.xlsx"
print("Duke ngarkuar datasetin nga UCI... Kjo mund të marrë pak kohë.")
df = pd.read_excel(DATA_URL)
df.shape

# %% [markdown]
# ## Shikim i shpejtë i strukturës

# %%
df.head()

# %%
df.info()

# %%
df.describe(include="all")

# %% [markdown]
# ## Kontrolle bazë (pa analizë të thelluar ende)
#
# Vetëm identifikim i problemeve — analiza e plotë bëhet në `02_eda_analysis.ipynb` (Hapi 2.1).

# %%
# Vlera mungesë për kolonë
df.isna().sum()

# %%
# Rreshta të dyfishuar (duplicates)
df.duplicated().sum()

# %%
# Quantity negative (mund të jenë kthime/refunds, InvoiceNo me prefiks 'C')
(df["Quantity"] < 0).sum() if "Quantity" in df.columns else "kolona 'Quantity' nuk u gjet"

# %%
# UnitPrice <= 0
(df["UnitPrice"] <= 0).sum() if "UnitPrice" in df.columns else "kolona 'UnitPrice' nuk u gjet"

# %% [markdown]
# ## Lista e problemeve të identifikuara
#
# _(Plotëso pasi të ekzekutosh qelizat më lart)_
#
# - [ ] CustomerID mungesë: ___ rreshta
# - [ ] Quantity negative: ___ rreshta
# - [ ] UnitPrice <= 0: ___ rreshta
# - [ ] Duplicates: ___ rreshta
# - [ ] Tjetër: ___
